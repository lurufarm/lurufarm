# %% [markdown]
# # 변수
# ## 01-02 대입 연산자
# ### 01-02-01. 대입 연산자 "="

# %%
team_name = "ohgiraffers"
my_team = team_name

# %% [markdown]
# ## 01-03 변수 이름 명명규칙
#
# ### 01-03-01. 암묵적 규칙

# %%
height = 161.3
a = 171.8
team_name = "오지라퍼스"
print(team_name)

# 파이썬은 변수명을 스네이크케이스로 작성하며, 대소문자를 구별한다.
Team_name = "Ohgiraffers"
print(Team_name)

# 한글 변수명을 지정할 수 있지만, 인코딩 등의 문제를 야기할 수 있으므로 사용을 지양한다.
우리팀 = "오지라퍼스!!"
print(우리팀)

# %% [markdown]
# ### 01-03-02. 문법 오류를 야기하는 규칙

# %% [markdown]
# 1. 영문과 숫자를 혼합해 작성할 수 있지만, 숫자를 가장 앞에 작성할 수 없다. (숫자로만 구성하는 것도 불가능)

# %%
team_1_name="오지라퍼스"
# 1_team_name = "오지라퍼스"
# 2025311 = "오늘날짜"

# %% [markdown]
# 2. 언더바(_)를 제외한 특수문자는 사용 불가하다.

# %%
# team_@_name = "오지라퍼스"
team__name = "어쩍우"

# %% [markdown]
# 3. 파이썬 예약어(if, elif, else, for, while, ...)을 사용할 수 없다.

# %%
# else = "오지라퍼스"
